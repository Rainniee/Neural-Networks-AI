# %% [markdown]
# ### Using batch_size = 32 to build the model

# %%
from __future__ import print_function

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop

from keras.datasets import cifar10
# Out:
# Using TensorFlow backend.

# %%
batch_size = 32
num_classes = 10
epochs = 20

# %%
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = x_train.reshape(-1, 3072)
x_test = x_test.reshape(-1, 3072)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 12s 0us/step
# 50000 train samples
# 10000 test samples

# %%
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,841,162
# Trainable params: 1,841,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 54s 1ms/step - loss: 2.0415 - acc: 0.2676 - val_loss: 1.9448 - val_acc: 0.3059
# Epoch 2/20
# 50000/50000 [==============================] - 52s 1ms/step - loss: 1.8632 - acc: 0.3240 - val_loss: 1.8084 - val_acc: 0.3468
# Epoch 3/20
# 50000/50000 [==============================] - 53s 1ms/step - loss: 1.8200 - acc: 0.3436 - val_loss: 1.8020 - val_acc: 0.3611
# Epoch 4/20
# 50000/50000 [==============================] - 54s 1ms/step - loss: 1.7958 - acc: 0.3548 - val_loss: 1.6911 - val_acc: 0.3929
# Epoch 5/20
# 50000/50000 [==============================] - 54s 1ms/step - loss: 1.7818 - acc: 0.3637 - val_loss: 1.6893 - val_acc: 0.4108
# Epoch 6/20
# 50000/50000 [==============================] - 53s 1ms/step - loss: 1.7777 - acc: 0.3652 - val_loss: 1.7442 - val_acc: 0.3720
# Epoch 7/20
# 50000/50000 [==============================] - 54s 1ms/step - loss: 1.7823 - acc: 0.3678 - val_loss: 1.6583 - val_acc: 0.4102
# Epoch 8/20
# 50000/50000 [==============================] - 53s 1ms/step - loss: 1.7764 - acc: 0.3654 - val_loss: 1.6779 - val_acc: 0.4151
# Epoch 9/20
# 50000/50000 [==============================] - 53s 1ms/step - loss: 1.7745 - acc: 0.3687 - val_loss: 1.6824 - val_acc: 0.3896
# Epoch 10/20
# 50000/50000 [==============================] - 54s 1ms/step - loss: 1.7757 - acc: 0.3723 - val_loss: 1.7369 - val_acc: 0.3623
# Epoch 11/20
# 50000/50000 [==============================] - 54s 1ms/step - loss: 1.7775 - acc: 0.3686 - val_loss: 1.7402 - val_acc: 0.3777
# Epoch 12/20
# 50000/50000 [==============================] - 53s 1ms/step - loss: 1.7798 - acc: 0.3707 - val_loss: 1.6581 - val_acc: 0.4135
# Epoch 13/20
# 50000/50000 [==============================] - 53s 1ms/step - loss: 1.7811 - acc: 0.3696 - val_loss: 1.7479 - val_acc: 0.3556
# Epoch 14/20
# 50000/50000 [==============================] - 53s 1ms/step - loss: 1.7828 - acc: 0.3714 - val_loss: 1.9002 - val_acc: 0.3154
# Epoch 15/20
# 50000/50000 [==============================] - 53s 1ms/step - loss: 1.7853 - acc: 0.3679 - val_loss: 1.8946 - val_acc: 0.3368
# Epoch 16/20
# 50000/50000 [==============================] - 53s 1ms/step - loss: 1.7799 - acc: 0.3698 - val_loss: 1.7508 - val_acc: 0.3665
# Epoch 17/20
# 50000/50000 [==============================] - 53s 1ms/step - loss: 1.7901 - acc: 0.3656 - val_loss: 1.6982 - val_acc: 0.3865
# Epoch 18/20
# 50000/50000 [==============================] - 53s 1ms/step - loss: 1.7957 - acc: 0.3651 - val_loss: 1.7550 - val_acc: 0.3844
# Epoch 19/20
# 50000/50000 [==============================] - 54s 1ms/step - loss: 1.7946 - acc: 0.3633 - val_loss: 2.0370 - val_acc: 0.3200
# Epoch 20/20
# 50000/50000 [==============================] - 54s 1ms/step - loss: 1.8018 - acc: 0.3611 - val_loss: 1.6876 - val_acc: 0.4002
# Test loss: 1.6876157873153685
# Test accuracy: 0.4002

# %% [markdown]
# *** Plot the result of accuracy and loss when batch_size=32***

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(0)
plt.plot(history.history['acc'],'r')
plt.plot(history.history['val_acc'],'g')
plt.xticks(np.arange(0, 24, 2.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Accuracy")
plt.title("Training Accuracy vs Validation Accuracy")
plt.legend(['train','validation'])

plt.figure(1)
plt.plot(history.history['loss'],'r')
plt.plot(history.history['val_loss'],'g')
plt.xticks(np.arange(0, 24, 2.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Loss")
plt.title("Training Loss vs Validation Loss")
plt.legend(['train','validation'])
 
plt.show()

# %% [markdown]
# ### Using batch_size = 64 to build the model

# %%
from __future__ import print_function

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop

from keras.datasets import cifar10

# %%
batch_size = 64
num_classes = 10
epochs = 20

# %%
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = x_train.reshape(-1, 3072)
x_test = x_test.reshape(-1, 3072)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 50000 train samples
# 10000 test samples

# %%
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 512)               1573376
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 1,841,162
# Trainable params: 1,841,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 35s 703us/step - loss: 2.1366 - acc: 0.2674 - val_loss: 1.8227 - val_acc: 0.3446
# Epoch 2/20
# 50000/50000 [==============================] - 32s 633us/step - loss: 1.8392 - acc: 0.3330 - val_loss: 1.8120 - val_acc: 0.3240
# Epoch 3/20
# 50000/50000 [==============================] - 31s 625us/step - loss: 1.7820 - acc: 0.3581 - val_loss: 1.6780 - val_acc: 0.3937
# Epoch 4/20
# 50000/50000 [==============================] - 31s 613us/step - loss: 1.7462 - acc: 0.3726 - val_loss: 1.7497 - val_acc: 0.3752
# Epoch 5/20
# 50000/50000 [==============================] - 31s 616us/step - loss: 1.7240 - acc: 0.3813 - val_loss: 1.7120 - val_acc: 0.3743
# Epoch 6/20
# 50000/50000 [==============================] - 31s 617us/step - loss: 1.6995 - acc: 0.3905 - val_loss: 1.7484 - val_acc: 0.3696
# Epoch 7/20
# 50000/50000 [==============================] - 31s 618us/step - loss: 1.6902 - acc: 0.3965 - val_loss: 1.6326 - val_acc: 0.4275
# Epoch 8/20
# 50000/50000 [==============================] - 31s 618us/step - loss: 1.6729 - acc: 0.4011 - val_loss: 1.7366 - val_acc: 0.3889
# Epoch 9/20
# 50000/50000 [==============================] - 31s 624us/step - loss: 1.6688 - acc: 0.4066 - val_loss: 1.6858 - val_acc: 0.3941
# Epoch 10/20
# 50000/50000 [==============================] - 31s 613us/step - loss: 1.6620 - acc: 0.4070 - val_loss: 1.6237 - val_acc: 0.4249
# Epoch 11/20
# 50000/50000 [==============================] - 31s 625us/step - loss: 1.6540 - acc: 0.4103 - val_loss: 1.6302 - val_acc: 0.4067
# Epoch 12/20
# 50000/50000 [==============================] - 32s 633us/step - loss: 1.6489 - acc: 0.4108 - val_loss: 1.7048 - val_acc: 0.3919
# Epoch 13/20
# 50000/50000 [==============================] - 31s 618us/step - loss: 1.6398 - acc: 0.4165 - val_loss: 1.6345 - val_acc: 0.4076
# Epoch 14/20
# 50000/50000 [==============================] - 31s 616us/step - loss: 1.6381 - acc: 0.4185 - val_loss: 1.6006 - val_acc: 0.4360
# Epoch 15/20
# 50000/50000 [==============================] - 31s 619us/step - loss: 1.6378 - acc: 0.4174 - val_loss: 1.6324 - val_acc: 0.4180
# Epoch 16/20
# 50000/50000 [==============================] - 31s 619us/step - loss: 1.6384 - acc: 0.4205 - val_loss: 1.5839 - val_acc: 0.4321
# Epoch 17/20
# 50000/50000 [==============================] - 31s 620us/step - loss: 1.6308 - acc: 0.4239 - val_loss: 1.6875 - val_acc: 0.4067
# Epoch 18/20
# 50000/50000 [==============================] - 31s 622us/step - loss: 1.6249 - acc: 0.4269 - val_loss: 1.6623 - val_acc: 0.3962
# Epoch 19/20
# 50000/50000 [==============================] - 31s 625us/step - loss: 1.6253 - acc: 0.4245 - val_loss: 1.5565 - val_acc: 0.4460
# Epoch 20/20
# 50000/50000 [==============================] - 31s 617us/step - loss: 1.6187 - acc: 0.4260 - val_loss: 1.6174 - val_acc: 0.4306
# Test loss: 1.6174224479675292
# Test accuracy: 0.4306

# %% [markdown]
# *** Plot the result of accuracy and loss when batch_size=64***

# %%
plt.figure(0)
plt.plot(history.history['acc'],'r')
plt.plot(history.history['val_acc'],'g')
plt.xticks(np.arange(0, 24, 2.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Accuracy")
plt.title("Training Accuracy vs Validation Accuracy")
plt.legend(['train','validation'])

plt.figure(1)
plt.plot(history.history['loss'],'r')
plt.plot(history.history['val_loss'],'g')
plt.xticks(np.arange(0, 24, 2.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Loss")
plt.title("Training Loss vs Validation Loss")
plt.legend(['train','validation'])
 
plt.show()

# %% [markdown]
# ### Using batch_size = 128 to build the model

# %%
batch_size = 128
num_classes = 10
epochs = 20

# %%
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = x_train.reshape(-1, 3072)
x_test = x_test.reshape(-1, 3072)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 50000 train samples
# 10000 test samples

# %%
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 512)               1573376
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 1,841,162
# Trainable params: 1,841,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 20s 397us/step - loss: 2.2096 - acc: 0.2466 - val_loss: 1.8429 - val_acc: 0.3372
# Epoch 2/20
# 50000/50000 [==============================] - 19s 386us/step - loss: 1.8634 - acc: 0.3288 - val_loss: 1.7631 - val_acc: 0.3626
# Epoch 3/20
# 50000/50000 [==============================] - 19s 382us/step - loss: 1.7902 - acc: 0.3550 - val_loss: 1.6752 - val_acc: 0.4075
# Epoch 4/20
# 50000/50000 [==============================] - 19s 383us/step - loss: 1.7431 - acc: 0.3743 - val_loss: 1.6522 - val_acc: 0.4278
# Epoch 5/20
# 50000/50000 [==============================] - 20s 396us/step - loss: 1.7069 - acc: 0.3871 - val_loss: 1.6749 - val_acc: 0.3962
# Epoch 6/20
# 50000/50000 [==============================] - 20s 390us/step - loss: 1.6773 - acc: 0.3968 - val_loss: 1.6213 - val_acc: 0.4334
# Epoch 7/20
# 50000/50000 [==============================] - 20s 392us/step - loss: 1.6612 - acc: 0.4059 - val_loss: 1.6049 - val_acc: 0.4442
# Epoch 8/20
# 50000/50000 [==============================] - 19s 389us/step - loss: 1.6438 - acc: 0.4143 - val_loss: 1.5879 - val_acc: 0.4452
# Epoch 9/20
# 50000/50000 [==============================] - 19s 384us/step - loss: 1.6308 - acc: 0.4176 - val_loss: 1.5530 - val_acc: 0.4428
# Epoch 10/20
# 50000/50000 [==============================] - 20s 394us/step - loss: 1.6130 - acc: 0.4239 - val_loss: 1.5810 - val_acc: 0.4340
# Epoch 11/20
# 50000/50000 [==============================] - 20s 391us/step - loss: 1.6031 - acc: 0.4266 - val_loss: 1.5900 - val_acc: 0.4395
# Epoch 12/20
# 50000/50000 [==============================] - 19s 383us/step - loss: 1.5951 - acc: 0.4316 - val_loss: 1.5457 - val_acc: 0.4537
# Epoch 13/20
# 50000/50000 [==============================] - 19s 386us/step - loss: 1.5844 - acc: 0.4354 - val_loss: 1.5822 - val_acc: 0.4406
# Epoch 14/20
# 50000/50000 [==============================] - 20s 390us/step - loss: 1.5716 - acc: 0.4403 - val_loss: 1.5953 - val_acc: 0.4220
# Epoch 15/20
# 50000/50000 [==============================] - 20s 403us/step - loss: 1.5724 - acc: 0.4390 - val_loss: 1.4918 - val_acc: 0.4777
# Epoch 16/20
# 50000/50000 [==============================] - 19s 381us/step - loss: 1.5551 - acc: 0.4440 - val_loss: 1.5515 - val_acc: 0.4460
# Epoch 17/20
# 50000/50000 [==============================] - 19s 382us/step - loss: 1.5542 - acc: 0.4472 - val_loss: 1.5251 - val_acc: 0.4637
# Epoch 18/20
# 50000/50000 [==============================] - 19s 378us/step - loss: 1.5514 - acc: 0.4465 - val_loss: 1.5629 - val_acc: 0.4394
# Epoch 19/20
# 50000/50000 [==============================] - 19s 377us/step - loss: 1.5433 - acc: 0.4512 - val_loss: 1.6458 - val_acc: 0.4102
# Epoch 20/20
# 50000/50000 [==============================] - 19s 378us/step - loss: 1.5390 - acc: 0.4507 - val_loss: 1.5216 - val_acc: 0.4583
# Test loss: 1.5215989738464355
# Test accuracy: 0.4583

# %% [markdown]
# *** Plot the result of accuracy and loss when batch_size=128***

# %%
plt.figure(0)
plt.plot(history.history['acc'],'r')
plt.plot(history.history['val_acc'],'g')
plt.xticks(np.arange(0, 22, 2.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Accuracy")
plt.title("Training Accuracy vs Validation Accuracy")
plt.legend(['train','validation'])

plt.figure(1)
plt.plot(history.history['loss'],'r')
plt.plot(history.history['val_loss'],'g')
plt.xticks(np.arange(0, 22, 2.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Loss")
plt.title("Training Loss vs Validation Loss")
plt.legend(['train','validation']) 

plt.show()

# %% [markdown]
# ### Plot the result of modifying the batch_size
